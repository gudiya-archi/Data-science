# %% [markdown]
# <a href="https://colab.research.google.com/github/gudiya-archi/Data-science/blob/main/Advanced_Matplotlib1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Session-24

# %% [markdown]
# * Colored Scatterplots

# %%
iris = pd.read_csv('/content/iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'])

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'])
plt.xlabel('sepal length')
plt.ylabel('petal length')
# Out:
# Text(0, 0.5, 'petal length')

# %%
iris = pd.read_csv('/content/iris.csv')
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 57    58            4.9           2.4            3.3           1.0
# 34    35            4.9           3.1            1.5           0.1
# 41    42            4.5           2.3            1.3           0.3
# 70    71            5.9           3.2            4.8           1.8
# 124  125            6.7           3.3            5.7           2.1
#
#              Species
# 57   Iris-versicolor
# 34       Iris-setosa
# 41       Iris-setosa
# 70   Iris-versicolor
# 124   Iris-virginica

# %%
iris['Species'] = iris['Species'].replace({'Iris-setosa':0, 'Iris-versicolor':1,'Iris-virginica':2})
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 109  110            7.2           3.6            6.1           2.5        2
# 99   100            5.7           2.8            4.1           1.3        1
# 65    66            6.7           3.1            4.4           1.4        1
# 94    95            5.6           2.7            4.2           1.3        1
# 60    61            5.0           2.0            3.5           1.0        1

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'])
plt.xlabel('sepal length')
plt.ylabel('petal length')
# Out:
# Text(0, 0.5, 'petal length')

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='viridis')
plt.xlabel('sepal length')
plt.ylabel('petal length')
# Out:
# Text(0, 0.5, 'petal length')

# %%
# cmap

plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='summer')
plt.xlabel('sepal length')
plt.ylabel('petal length')
# Out:
# Text(0, 0.5, 'petal length')

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='winter')
plt.xlabel('sepal length')
plt.ylabel('petal length')
# Out:
# Text(0, 0.5, 'petal length')

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet')
plt.xlabel('sepal length')
plt.ylabel('petal length')
# Out:
# Text(0, 0.5, 'petal length')

# %%
# cmap

plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet')
plt.xlabel('Sepal length')
plt.ylabel('Petal length')
plt.colorbar()

# %%
# cmap and alpha

plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet',alpha=0.3)
plt.xlabel('Sepal length')
plt.ylabel('Petal length')
plt.colorbar()

# %%
# cmap and alpha

plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet',alpha=0.7)
plt.xlabel('Sepal length')
plt.ylabel('Petal length')
plt.colorbar()

# %%
plt.figure(figsize=(15,7))

plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet',alpha=0.7)
plt.xlabel('Sepal length')
plt.ylabel('Petal length')
plt.colorbar()

# %%
# plt.figure(figsize=(3,1)) ......   size small ho jata hai aur big bhi ho jata hai

plt.figure(figsize=(3,1))

plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet',alpha=0.7)
plt.xlabel('Sepal length')
plt.ylabel('Petal length')
plt.colorbar()

# %% [markdown]
# Annotations

# %%
batters = pd.read_csv('/content/batter.csv')

# %%
batters.head(5)
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
batters.shape
# Out:
# (605, 4)

# %%
# batters = batters.head(100).sample(25,random_states=5)
