# %% [markdown]
# <a href="https://colab.research.google.com/github/gudiya-archi/Data-science/blob/main/Random_no1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# working with random
# randint
# seed
# shuffle
# choice

# %%
import numpy as np

# %%
np.random.random((2,3))
# Out:
# array([[0.9207999 , 0.29312801, 0.56678816],
#        [0.95371129, 0.18874753, 0.15779021]])

# %%
np.random.random((2,3,2))
# Out:
# array([[[0.99792858, 0.49036445],
#         [0.82652559, 0.11262852],
#         [0.7622799 , 0.17518979]],
#
#        [[0.38928719, 0.27251321],
#         [0.72334951, 0.31962483],
#         [0.1102545 , 0.8994596 ]]])

# %%
np.random.randint(1,100,12)
# Out:
# array([12, 77, 31, 23, 59, 93, 82, 90, 94, 13, 76,  5])

# %%
np.random.randint(1,100,12).reshape(3,4)
# Out:
# array([[78, 22,  5, 43],
#        [66, 77, 77,  4],
#        [16, 67, 46, 24]])

# %%
np.random.seed(0)
np.random.randint(1,100,12).reshape(3,4)
# Out:
# array([[45, 48, 65, 68],
#        [68, 10, 84, 22],
#        [37, 88, 71, 89]])

# %%
np.random.seed(0)
np.random.randint(1,100,12).reshape(3,4)
# Out:
# array([[45, 48, 65, 68],
#        [68, 10, 84, 22],
#        [37, 88, 71, 89]])

# %%
np.random.randint(1,100,12).reshape(3,4)
# Out:
# array([[89, 13, 59, 66],
#        [40, 88, 47, 89],
#        [82, 38, 26, 78]])

# %%
np.random.seed(1)
np.random.randint(1,100,12).reshape(3,4)
# Out:
# array([[38, 13, 73, 10],
#        [76,  6, 80, 65],
#        [17,  2, 77, 72]])

# %%
# shuffle
a = np.array([12,41,33,67,89,100])
print(a)
# Out:
# [ 12  41  33  67  89 100]

# %%
np.random.shuffle(a)
a
# Out:
# array([ 67,  33,  12,  41,  89, 100])

# %%
np.random.choice(a,3)
# Out:
# array([33, 67, 67])

# %%
np.random.choice(a,3,replace=False)
# Out:
# array([ 33, 100,  67])

# %%
# working with images
import cv2

# %%
# read the image
cv2.imread('/content/dance&garba.png')
# Out:
# array([[[147, 215, 233],
#         [149, 217, 234],
#         [149, 217, 234],
#         ...,
#         [255, 158,  50],
#         [254, 154,  48],
#         [255, 154,  51]],
#
#        [[149, 217, 234],
#         [150, 217, 234],
#         [150, 217, 234],
#         ...,
#         [255, 157,  50],
#         [254, 154,  49],
#         [255, 154,  51]],
#
#        [[153, 219, 235],
#         [152, 218, 235],
#         [151, 219, 236],
#         ...,
#         [255, 155,  50],
#         [255, 154,  51],
#         [255, 154,  51]],
#
#        ...,
#
#        [[ 88,   5, 216],
#         [ 88,   8, 216],
#         [ 87,   8, 215],
#         ...,
#         [230,  61, 124],
#         [232,  61, 123],
#         [231,  60, 122]],
#
#        [[129,  68, 227],
#         [131,  71, 227],
#         [131,  71, 227],
#         ...,
#         [236, 110, 157],
#         [238, 109, 156],
#         [237, 109, 155]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
type(cv2.imread('/content/dance&garba.png'))
# Out:
# numpy.ndarray

# %%
img = cv2.imread('/content/dance&garba.png')

# %%
# show array -> shape
img.shape
# Out:
# (1748, 1240, 3)

# %%
# show image
import matplotlib.pyplot as plt

plt.imshow(img)

# %%
plt.imshow(np.flip(img))

# %%
plt.imshow(np.flip(img,axis=0))

# %%
plt.imshow(np.flip(img,axis=1))

# %%
# flip
import numpy as np

a = np.arange(6).reshape(2,3)
a
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
np.flip(a)
# Out:
# array([[5, 4, 3],
#        [2, 1, 0]])

# %%
# clip -> fade
np.clip(a,2,3)
# Out:
# array([[2, 2, 2],
#        [3, 3, 3]])

# %%
img
# Out:
# array([[[147, 215, 233],
#         [149, 217, 234],
#         [149, 217, 234],
#         ...,
#         [255, 158,  50],
#         [254, 154,  48],
#         [255, 154,  51]],
#
#        [[149, 217, 234],
#         [150, 217, 234],
#         [150, 217, 234],
#         ...,
#         [255, 157,  50],
#         [254, 154,  49],
#         [255, 154,  51]],
#
#        [[153, 219, 235],
#         [152, 218, 235],
#         [151, 219, 236],
#         ...,
#         [255, 155,  50],
#         [255, 154,  51],
#         [255, 154,  51]],
#
#        ...,
#
#        [[ 88,   5, 216],
#         [ 88,   8, 216],
#         [ 87,   8, 215],
#         ...,
#         [230,  61, 124],
#         [232,  61, 123],
#         [231,  60, 122]],
#
#        [[129,  68, 227],
#         [131,  71, 227],
#         [131,  71, 227],
#         ...,
#         [236, 110, 157],
#         [238, 109, 156],
#         [237, 109, 155]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img.max()
# Out:
# np.uint8(255)

# %%
img.min()
# Out:
# np.uint8(0)

# %%
plt.imshow(np.clip(img,0,100))

# %%
# negative
plt.imshow(255 - img)

# %%
# trim
plt.imshow(img[100:500,100:500,:])

# %%
plt.imshow(img[100:500,100:900,:])

# %%
plt.imshow(img[100:500,50:500,:])

# %%
plt.imshow(img[100:900,50:900,:])

# %%
#  plot histogram
plt.hist(img.flatten(),bins=255)
# Out:
# (array([141061.,  48516.,   8921.,  88687.,   5115.,   4666.,   4545.,
#           4385.,   4497.,   4114.,   3851.,   3288.,   3223.,   2796.,
#           2890.,   7628.,   3272.,   2763.,   2630.,   2453.,   2479.,
#           2702.,   2657.,   2741.,  25146.,   2868.,   2832.,   2884.,
#           3069.,   3062.,   3290.,   3295.,   3580.,   3679.,   3727.,
#           3803.,   3664.,   4022.,   4952.,   5667.,   6254.,   5155.,
#           5111.,   4616.,   4971.,   5149.,   4845.,   4752.,   4546.,
#           4697.,   4429.,   4108.,   4327.,   4262.,   4417.,   4381.,
#           4581.,   4777.,   5008.,   4996.,   4701.,   4924.,   5320.,
#           5136.,   5315.,   5490.,   5400.,   6154.,   6460.,  89851.,
#           6401.,   6763.,   6701.,   7008.,   7729.,  91153.,  12652.,
#           7906.,   7616.,   7372.,   7628.,   7709.,   7908.,   8118.,
#           9333.,   9292.,   9867.,  10281.,  11247.,  11250.,  11027.,
# ...

# %%
# structured arrays
a = np.array([1,'hello',True,1.5])
a
# Out:
# array(['1', 'hello', 'True', '1.5'], dtype='<U32')

# %%
a[0]
# Out:
# np.str_('1')

# %%
type (a[0])
# Out:
# numpy.str_

# %%
a[0] *1100
# Out:
# '...'

# %%
a[0] / 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-39851458.py in <cell line: 0>()
# ----> 1 a[0] / 100
#
# TypeError: unsupported operand type(s) for /: 'numpy.str_' and 'int'

# %%
  # name, iq , cgpa , placed

# %%
dt = np.dtype(
    [
        ('name','U20'),
        ('iq',np.int32),
        ('cgpa',np.float64),
        ('placed','U20')
    ]
)

# %%
dt
# Out:
# dtype([('name', '<U20'), ('iq', '<i4'), ('cgpa', '<f8'), ('placed', '<U20')])

# %%
stu = np.array(
    [
        ('nitish',100,6.66,'yes'),
        ('ankit',120,8.9,'yes'),
        ('rahul',80,7.3,'no')
    ],dtype=dt
)

stu
# Out:
# array([('nitish', 100, 6.66, 'yes'), ('ankit', 120, 8.9 , 'yes'),
#        ('rahul',  80, 7.3 , 'no')],
#       dtype=[('name', '<U20'), ('iq', '<i4'), ('cgpa', '<f8'), ('placed', '<U20')])

# %%
stu[0]
# Out:
# np.void(('nitish', 100, 6.66, 'yes'), dtype=[('name', '<U20'), ('iq', '<i4'), ('cgpa', '<f8'), ('placed', '<U20')])

# %%
stu[0][0]
# Out:
# np.str_('nitish')

# %%
stu[0][1]
# Out:
# np.int32(100)

# %%
stu[0][1]/10
# Out:
# np.float64(10.0)

# %%
stu[2]
# Out:
# np.void(('rahul', 80, 7.3, 'no'), dtype=[('name', '<U20'), ('iq', '<i4'), ('cgpa', '<f8'), ('placed', '<U20')])

# %%
stu['name']
# Out:
# array(['nitish', 'ankit', 'rahul'], dtype='<U20')

# %%
stu['iq']
# Out:
# array([100, 120,  80], dtype=int32)

# %%
stu['cgpa']
# Out:
# array([6.66, 8.9 , 7.3 ])

# %%
stu['placed']
# Out:
# array(['yes', 'yes', 'no'], dtype='<U20')

# %%
# save and load numpy objects
np.save('student.npy',stu)

# %%
# remaining functions

# --> np.swapaxes
# -->np.uniform
# --> np.count_nonzero
# --> np.tile
# --> np.repeat
# --> np.allclose
